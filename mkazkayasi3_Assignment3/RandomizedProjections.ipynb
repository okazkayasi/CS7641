# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from matplotlib import cm
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.random_projection import GaussianRandomProjection
from sklearn.covariance import ShrunkCovariance, LedoitWolf
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
wine_dataset = pd.read_csv("wine_dataset.csv")
ufc_dataset = pd.read_csv("ufc_data.csv")
ufc_dataset.loc[ufc_dataset["Winner"] == "Red", "Winner"] = 1
ufc_dataset.loc[ufc_dataset["Winner"] == "Blue", "Winner"] = 0
ufc_dataset.drop(["no_of_rounds"], axis=1 ,inplace=True)
# al zero
ufc_dataset.drop(["B_draw"], axis=1 ,inplace=True)
ufc_dataset.drop(["R_draw"], axis=1 ,inplace=True)

ufcX = ufc_dataset.drop("Winner", 1).copy().values
ufcY = ufc_dataset["Winner"].copy().values
ufc_x_df = ufc_dataset.drop("Winner",1)

wineX = wine_dataset.drop("class", 1).copy().values
wineY = wine_dataset["class"].copy().values
wine_x_df = wine_dataset.drop("class",1)


min_max_scaler = preprocessing.MinMaxScaler()
ufcX = min_max_scaler.fit_transform(ufcX)
ufcX_df = pd.DataFrame(ufcX, columns=ufc_x_df.columns)
wineX = min_max_scaler.fit_transform(wineX)
wineX_df = pd.DataFrame(wineX, columns=wine_x_df.columns)

# %%
ufcX.shape
dims_ufc = list(range(2,150,1))

# %%
rc_errors = {}
for dim in dims_ufc:
    grp = GaussianRandomProjection(n_components=dim, random_state=44)
    x_prime = grp.fit_transform(ufcX_df.values)
    
    # reconstruction
    A = np.linalg.pinv(grp.components_.T)
    reconstructed = np.dot(x_prime, A)
    rc_err = mean_squared_error(ufcX_df.values, reconstructed)    
    rc_errors[dim] = rc_err
#     print(dim, ": ", rc_err)
plt.figure()
plt.plot(list(rc_errors.keys()), list(rc_errors.values()))
plt.xlabel("Number of dimensions")
plt.ylabel("RMSE")
plt.show()

# %%
comp = 40
grp = GaussianRandomProjection(n_components=comp, random_state=44)
grp_result = grp.fit_transform(ufcX_df.values)
for i in range(comp):
    field_name = "grp-"+str(i)
    ufcX_df[field_name] = grp_result[:,i]
    ufc_dataset[field_name] = grp_result[:,i]
ufcX_grp_40 = grp_result

# %%
ufcX_df.head()
# Out:
#    title_bout  B_current_lose_streak  B_current_win_streak  B_avg_BODY_att  \
# 0         1.0                    0.0              0.333333        0.187755
# 1         1.0                    0.0              0.250000        0.297959
# 2         0.0                    0.0              0.250000        0.313364
# 3         0.0                    0.0              0.333333        0.346939
# 4         0.0                    0.0              0.083333        0.346939
#
#    B_avg_BODY_landed  B_avg_CLINCH_att  B_avg_CLINCH_landed  \
# 0           0.153846          0.002299             0.000000
# 1           0.233333          0.135632             0.107353
# 2           0.290323          0.077494             0.064516
# 3           0.358974          0.158046             0.161765
# 4           0.371795          0.028736             0.029412
#
#    B_avg_DISTANCE_att  B_avg_DISTANCE_landed  B_avg_GROUND_att  ...    grp-30  \
# 0            0.230996               0.158462          0.029545  ...  0.495685
# 1            0.460148               0.323846          0.027273  ...  0.677525
# 2            0.312701               0.296774          0.062683  ...  0.230588
# 3            0.404059               0.375000          0.147727  ...  0.641775
# 4            0.741697               0.457692          0.000000  ...  0.433048
#
#      grp-31    grp-32    grp-33    grp-34    grp-35    grp-36    grp-37  \
# 0  0.447574 -0.509854  0.343594  0.164113 -0.190553 -0.389247  0.098851
# 1  0.390540 -0.848316  0.370295 -0.209958 -0.183859 -0.571965 -0.467169
# 2  0.388793 -0.725148  0.800119 -0.042485 -0.511966 -0.711594 -0.567176
# 3  0.466112 -0.846821  0.561776  0.369599 -0.566446 -0.497872  0.454809
# 4 -0.274796 -0.303885 -0.436417 -0.095682 -0.579802 -0.803924 -0.225149
#
#      grp-38    grp-39
# 0 -0.379780  0.940379
# 1  0.102339  0.984703
# 2 -0.143515  0.617629
# 3  0.231469  0.519477
# 4  0.305699  1.398567
#
# [5 rows x 196 columns]

# %%
rndperm = np.random.permutation(ufc_dataset.shape[0])

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="grp-0", y="grp-1",
    hue="Winner",
    palette=sns.color_palette("hls", 2),
    data=ufc_dataset,
    legend="full",
    alpha=0.3
)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=ufc_dataset.loc[rndperm,:]["grp-0"], 
    ys=ufc_dataset.loc[rndperm,:]["grp-1"], 
    zs=ufc_dataset.loc[rndperm,:]["grp-2"], 
    c=ufc_dataset.loc[rndperm,:]["Winner"], 
    cmap='tab10'
)
ax.set_xlabel('grp-one')
ax.set_ylabel('grp-two')
ax.set_zlabel('grp-three')
plt.show()

# %% [markdown]
# ## UFC CLustering on GRP

# %%
from sklearn.cluster import KMeans
clusters = list(range(2,31,1))
# Out:
# /home/okazkayasi/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, homogeneity_score
silh = {}
homog = {}
for cluster in clusters:
    kmeans = KMeans(n_clusters=cluster, n_init=50, max_iter=1000, random_state=44, n_jobs=-2).fit(ufcX_grp_40)
    label = kmeans.labels_
    sil_coeff = silhouette_score(ufcX_grp_40, label, metric='euclidean')
    homog_score = homogeneity_score(ufcY, label)
    silh[cluster] = sil_coeff
    homog[cluster] = homog_score
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(cluster, sil_coeff))
    print("For n_clusters={}, The homogeneity_score is {}".format(cluster, homog_score))
plt.figure()
plt.plot(list(silh.keys()), list(silh.values()))
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
plt.show()
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.15757452048814416
# For n_clusters=2, The homogeneity_score is 0.00022480154455690123
# For n_clusters=3, The Silhouette Coefficient is 0.10485655018826091
# For n_clusters=3, The homogeneity_score is 0.005228622527836073
# For n_clusters=4, The Silhouette Coefficient is 0.10566539391837577
# For n_clusters=4, The homogeneity_score is 0.005018300217814566
# For n_clusters=5, The Silhouette Coefficient is 0.09706223378533768
# For n_clusters=5, The homogeneity_score is 0.005104897972812145
# For n_clusters=6, The Silhouette Coefficient is 0.09642497710483723
# For n_clusters=6, The homogeneity_score is 0.005936614090245952
# For n_clusters=7, The Silhouette Coefficient is 0.09857699091480153
# For n_clusters=7, The homogeneity_score is 0.006279865991959295
# For n_clusters=8, The Silhouette Coefficient is 0.09429010824743453
# For n_clusters=8, The homogeneity_score is 0.006581110592832969
# For n_clusters=9, The Silhouette Coefficient is 0.10134263065811183
# For n_clusters=9, The homogeneity_score is 0.006004247140984422
# For n_clusters=10, The Silhouette Coefficient is 0.10394319396564415
# For n_clusters=10, The homogeneity_score is 0.006955563906994824
# For n_clusters=11, The Silhouette Coefficient is 0.1108768127678763
# For n_clusters=11, The homogeneity_score is 0.008053700696889656
# For n_clusters=12, The Silhouette Coefficient is 0.1130760343524156
# For n_clusters=12, The homogeneity_score is 0.007859324507254906
# For n_clusters=13, The Silhouette Coefficient is 0.116228318525185
# For n_clusters=13, The homogeneity_score is 0.00803989402279578
# For n_clusters=14, The Silhouette Coefficient is 0.11825887361756948
# For n_clusters=14, The homogeneity_score is 0.008118564444882057
# For n_clusters=15, The Silhouette Coefficient is 0.11654843697983722
# For n_clusters=15, The homogeneity_score is 0.009258428056391325
# For n_clusters=16, The Silhouette Coefficient is 0.1229137943938812
# For n_clusters=16, The homogeneity_score is 0.007533826971116057
# For n_clusters=17, The Silhouette Coefficient is 0.12223497837847494
# For n_clusters=17, The homogeneity_score is 0.011285668042295324
# For n_clusters=18, The Silhouette Coefficient is 0.11754068057561036
# For n_clusters=18, The homogeneity_score is 0.016014229243578516
# For n_clusters=19, The Silhouette Coefficient is 0.11715749642240274
# For n_clusters=19, The homogeneity_score is 0.01579819363024382
# For n_clusters=20, The Silhouette Coefficient is 0.11644842592543865
# For n_clusters=20, The homogeneity_score is 0.015303698008180924
# For n_clusters=21, The Silhouette Coefficient is 0.11032924558232861
# For n_clusters=21, The homogeneity_score is 0.01572531368326186
# For n_clusters=22, The Silhouette Coefficient is 0.11747247850655107
# For n_clusters=22, The homogeneity_score is 0.011717846771261739
# For n_clusters=23, The Silhouette Coefficient is 0.11230626568518924
# For n_clusters=23, The homogeneity_score is 0.015543450257226907
# For n_clusters=24, The Silhouette Coefficient is 0.11523334150451586
# For n_clusters=24, The homogeneity_score is 0.015619864251455578
# For n_clusters=25, The Silhouette Coefficient is 0.11654455163482445
# For n_clusters=25, The homogeneity_score is 0.016818086654312427
# For n_clusters=26, The Silhouette Coefficient is 0.1117325245471335
# For n_clusters=26, The homogeneity_score is 0.013691322889217148
# For n_clusters=27, The Silhouette Coefficient is 0.1104669781248229
# For n_clusters=27, The homogeneity_score is 0.014669397021971583
# For n_clusters=28, The Silhouette Coefficient is 0.11141740729664407
# For n_clusters=28, The homogeneity_score is 0.01853085827211682
# For n_clusters=29, The Silhouette Coefficient is 0.11228800690934741
# For n_clusters=29, The homogeneity_score is 0.018557321570211904
# For n_clusters=30, The Silhouette Coefficient is 0.102191020782905
# For n_clusters=30, The homogeneity_score is 0.023015394840125963

# %%
from sklearn.mixture import GaussianMixture
silh_EM = {}
homog_EM = {}
log_likelihood_EM = {}
for cluster in clusters:
    gmm = GaussianMixture(n_components=cluster, max_iter=100, random_state=44, 
                          n_init=5).fit(ufcX_grp_40)
    label = gmm.predict(ufcX_grp_40)
    sil_coeff = silhouette_score(ufcX_grp_40, label, metric='euclidean')
    homog_score = homogeneity_score(ufcY, label)
    silh_EM[cluster] = sil_coeff
    homog_EM[cluster] = homog_score
    log_likelihood_EM[cluster] = gmm.score(ufcX_grp_40)
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(cluster, sil_coeff))
    print("For n_clusters={}, The homogeneity_score is {}".format(cluster, homog_score))
    print("For n_clusters={}, The log_likelihood score is {}".format(cluster, log_likelihood_EM[cluster]))

    
plt.figure()
plt.plot(list(silh_EM.keys()), list(silh_EM.values()))
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
plt.show()
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.08586003689940055
# For n_clusters=2, The homogeneity_score is 0.0033409125626836468
# For n_clusters=2, The log_likelihood score is -1.4645640695981479
# For n_clusters=3, The Silhouette Coefficient is 0.09977080014859674
# For n_clusters=3, The homogeneity_score is 0.004050560074094389
# For n_clusters=3, The log_likelihood score is -0.462106129708029
# For n_clusters=4, The Silhouette Coefficient is 0.09411057919662721
# For n_clusters=4, The homogeneity_score is 0.006412648189075376
# For n_clusters=4, The log_likelihood score is 0.6702615792365747
# For n_clusters=5, The Silhouette Coefficient is 0.08649689159976119
# For n_clusters=5, The homogeneity_score is 0.0063712043512098625
# For n_clusters=5, The log_likelihood score is 1.6353810470617431
# For n_clusters=6, The Silhouette Coefficient is 0.08755991088672388
# For n_clusters=6, The homogeneity_score is 0.006204222401717492
# For n_clusters=6, The log_likelihood score is 2.4362041397192966
# For n_clusters=7, The Silhouette Coefficient is 0.08248851309289532
# For n_clusters=7, The homogeneity_score is 0.00778844050033835
# For n_clusters=7, The log_likelihood score is 3.239421016060992
# For n_clusters=8, The Silhouette Coefficient is 0.08250652778727141
# For n_clusters=8, The homogeneity_score is 0.009794321613756898
# For n_clusters=8, The log_likelihood score is 3.8555416976616192
# For n_clusters=9, The Silhouette Coefficient is 0.09817627123915815
# For n_clusters=9, The homogeneity_score is 0.007278749629685047
# For n_clusters=9, The log_likelihood score is 3.9907420304604133
# For n_clusters=10, The Silhouette Coefficient is 0.0916466808567261
# For n_clusters=10, The homogeneity_score is 0.008198113814104988
# For n_clusters=10, The log_likelihood score is 4.581469055020601
# For n_clusters=11, The Silhouette Coefficient is 0.10142223271295257
# For n_clusters=11, The homogeneity_score is 0.008964422401448185
# For n_clusters=11, The log_likelihood score is 4.996484384938229
# For n_clusters=12, The Silhouette Coefficient is 0.10092377129872006
# For n_clusters=12, The homogeneity_score is 0.007782704626505875
# For n_clusters=12, The log_likelihood score is 5.248943516228809
# For n_clusters=13, The Silhouette Coefficient is 0.11175734235167312
# For n_clusters=13, The homogeneity_score is 0.008641182546182482
# For n_clusters=13, The log_likelihood score is 5.641600642880546
# For n_clusters=14, The Silhouette Coefficient is 0.1155133888172742
# For n_clusters=14, The homogeneity_score is 0.008874509398344015
# For n_clusters=14, The log_likelihood score is 6.086950197128127
# For n_clusters=15, The Silhouette Coefficient is 0.11225188270920813
# For n_clusters=15, The homogeneity_score is 0.010791996767722613
# For n_clusters=15, The log_likelihood score is 6.441938824634735
# For n_clusters=16, The Silhouette Coefficient is 0.10678640160481949
# For n_clusters=16, The homogeneity_score is 0.013458578589237675
# For n_clusters=16, The log_likelihood score is 6.620867188306867
# For n_clusters=17, The Silhouette Coefficient is 0.11602531510959083
# For n_clusters=17, The homogeneity_score is 0.011653600187375228
# For n_clusters=17, The log_likelihood score is 7.053843335193544
# For n_clusters=18, The Silhouette Coefficient is 0.10510420806417825
# For n_clusters=18, The homogeneity_score is 0.017242581833645618
# For n_clusters=18, The log_likelihood score is 7.318942873020546
# For n_clusters=19, The Silhouette Coefficient is 0.10724537481312513
# For n_clusters=19, The homogeneity_score is 0.019172164807671692
# For n_clusters=19, The log_likelihood score is 7.491409985849445
# For n_clusters=20, The Silhouette Coefficient is 0.10080511851403624
# For n_clusters=20, The homogeneity_score is 0.01549897392627999
# For n_clusters=20, The log_likelihood score is 7.87116838839335
# For n_clusters=21, The Silhouette Coefficient is 0.10455746988126788
# For n_clusters=21, The homogeneity_score is 0.017075825274039447
# For n_clusters=21, The log_likelihood score is 8.253532635173709
# For n_clusters=22, The Silhouette Coefficient is 0.10592333246514406
# For n_clusters=22, The homogeneity_score is 0.017564250139407423
# For n_clusters=22, The log_likelihood score is 8.589286576886044
# For n_clusters=23, The Silhouette Coefficient is 0.10725075450653711
# For n_clusters=23, The homogeneity_score is 0.018677023959204616
# For n_clusters=23, The log_likelihood score is 8.780833765105859
# For n_clusters=24, The Silhouette Coefficient is 0.10955155609199596
# For n_clusters=24, The homogeneity_score is 0.021564414948774813
# For n_clusters=24, The log_likelihood score is 9.041415622779338
# For n_clusters=25, The Silhouette Coefficient is 0.10983073151389051
# For n_clusters=25, The homogeneity_score is 0.023677617541489882
# For n_clusters=25, The log_likelihood score is 9.302906215397005
# For n_clusters=26, The Silhouette Coefficient is 0.09774070559722774
# For n_clusters=26, The homogeneity_score is 0.01810861946986042
# For n_clusters=26, The log_likelihood score is 9.63170940098587
# For n_clusters=27, The Silhouette Coefficient is 0.10874857108975702
# For n_clusters=27, The homogeneity_score is 0.0209665552272371
# For n_clusters=27, The log_likelihood score is 10.083884833468547
# For n_clusters=28, The Silhouette Coefficient is 0.1105940549576423
# For n_clusters=28, The homogeneity_score is 0.021706307962277373
# For n_clusters=28, The log_likelihood score is 10.344193877685447
# For n_clusters=29, The Silhouette Coefficient is 0.1151440237303231
# For n_clusters=29, The homogeneity_score is 0.022053947352831272
# For n_clusters=29, The log_likelihood score is 10.747068053060834
# For n_clusters=30, The Silhouette Coefficient is 0.1105690765642859
# For n_clusters=30, The homogeneity_score is 0.022603621527111074
# For n_clusters=30, The log_likelihood score is 10.972469582477007

# %% [markdown]
# # WINE DATASET

# %%
dims_wine = list(range(1,14,1))

# %%
rc_errors_wine = {}
for dim in dims_wine:
    grp = GaussianRandomProjection(n_components=dim, random_state=44)
    x_prime = grp.fit_transform(wineX_df.values)
    
    # reconstruction
    A = np.linalg.pinv(grp.components_.T)
    reconstructed = np.dot(x_prime, A)
    rc_err = mean_squared_error(wineX_df.values, reconstructed)    
    rc_errors_wine[dim] = rc_err
#     print(dim, ": ", rc_err)
plt.figure()
plt.plot(list(rc_errors_wine.keys()), list(rc_errors_wine.values()))
plt.xlabel("dimension")
plt.ylabel("RMSE")
plt.show()

# %%
comp = 9
grp = GaussianRandomProjection(n_components=comp, random_state=44)
grp_result = grp.fit_transform(wineX_df.values)
for i in range(comp):
    field_name = "grp-"+str(i)
    wineX_df[field_name] = grp_result[:,i]
    wine_dataset[field_name] = grp_result[:,i]
wineX_grp_9 = grp_result

# %%
rndperm = np.random.permutation(wine_dataset.shape[0])

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="grp-0", y="grp-1",
    hue="class",
    palette=sns.color_palette("tab10", 3),
    data=wine_dataset,
    legend="full",
    alpha=0.3
)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=wine_dataset.loc[rndperm,:]["grp-0"], 
    ys=wine_dataset.loc[rndperm,:]["grp-1"], 
    zs=wine_dataset.loc[rndperm,:]["grp-2"], 
    c=wine_dataset.loc[rndperm,:]["class"], 
    cmap='tab10'
)
ax.set_xlabel('grp-one')
ax.set_ylabel('grp-two')
ax.set_zlabel('grp-three')
plt.show()

# %% [markdown]
# ## Wine Clustering on ICA

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, homogeneity_score
silh_wine = {}
homog_wine = {}
for cluster in clusters:
    kmeans = KMeans(n_clusters=cluster, n_init=50, max_iter=1000, random_state=44, n_jobs=-2).fit(wineX_grp_9)
    label = kmeans.labels_
    sil_coeff = silhouette_score(wineX_grp_9, label, metric='euclidean')
    homog_score = homogeneity_score(wineY, label)
    silh_wine[cluster] = sil_coeff
    homog_wine[cluster] = homog_score
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(cluster, sil_coeff))
    print("For n_clusters={}, The homogeneity_score is {}".format(cluster, homog_score))
plt.figure()
plt.plot(list(silh_wine.keys()), list(silh_wine.values()))
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
plt.show()
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.28722754816246643
# For n_clusters=2, The homogeneity_score is 0.24850199254159513
# For n_clusters=3, The Silhouette Coefficient is 0.24351246430429552
# For n_clusters=3, The homogeneity_score is 0.3391738147699275
# For n_clusters=4, The Silhouette Coefficient is 0.2037649838036307
# For n_clusters=4, The homogeneity_score is 0.35040057048847423
# For n_clusters=5, The Silhouette Coefficient is 0.1828601208772538
# For n_clusters=5, The homogeneity_score is 0.40829901208852365
# For n_clusters=6, The Silhouette Coefficient is 0.1640620640326337
# For n_clusters=6, The homogeneity_score is 0.41526283288639987
# For n_clusters=7, The Silhouette Coefficient is 0.1641144815071051
# For n_clusters=7, The homogeneity_score is 0.43703005981645
# For n_clusters=8, The Silhouette Coefficient is 0.15108926258170277
# For n_clusters=8, The homogeneity_score is 0.44829655744574093
# For n_clusters=9, The Silhouette Coefficient is 0.1510595072954485
# For n_clusters=9, The homogeneity_score is 0.4518128015745806
# For n_clusters=10, The Silhouette Coefficient is 0.14116228443693088
# For n_clusters=10, The homogeneity_score is 0.4572306550193126
# For n_clusters=11, The Silhouette Coefficient is 0.13507788016310293
# For n_clusters=11, The homogeneity_score is 0.4654356348387461
# For n_clusters=12, The Silhouette Coefficient is 0.13245675155931388
# For n_clusters=12, The homogeneity_score is 0.46295158632867356
# For n_clusters=13, The Silhouette Coefficient is 0.13283330333224777
# For n_clusters=13, The homogeneity_score is 0.46750971599379326
# For n_clusters=14, The Silhouette Coefficient is 0.12875979414059222
# For n_clusters=14, The homogeneity_score is 0.46296955651639593
# For n_clusters=15, The Silhouette Coefficient is 0.12814230174649682
# For n_clusters=15, The homogeneity_score is 0.46529071833536145
# For n_clusters=16, The Silhouette Coefficient is 0.12493426511846314
# For n_clusters=16, The homogeneity_score is 0.4746028714539031
# For n_clusters=17, The Silhouette Coefficient is 0.1250047926743613
# For n_clusters=17, The homogeneity_score is 0.47337708031646003
# For n_clusters=18, The Silhouette Coefficient is 0.1216121329741054
# For n_clusters=18, The homogeneity_score is 0.4796151778048681
# For n_clusters=19, The Silhouette Coefficient is 0.12422578635843938
# For n_clusters=19, The homogeneity_score is 0.48744760189467323
# For n_clusters=20, The Silhouette Coefficient is 0.12311260584533884
# For n_clusters=20, The homogeneity_score is 0.49306241028590153
# For n_clusters=21, The Silhouette Coefficient is 0.12102497556874478
# For n_clusters=21, The homogeneity_score is 0.4846354401440487
# For n_clusters=22, The Silhouette Coefficient is 0.12333574151664166
# For n_clusters=22, The homogeneity_score is 0.4903566955737345
# For n_clusters=23, The Silhouette Coefficient is 0.12014823084273994
# For n_clusters=23, The homogeneity_score is 0.49690029811944614
# For n_clusters=24, The Silhouette Coefficient is 0.11991662807279352
# For n_clusters=24, The homogeneity_score is 0.4943501927999572
# For n_clusters=25, The Silhouette Coefficient is 0.1203993016310312
# For n_clusters=25, The homogeneity_score is 0.4868415059652733
# For n_clusters=26, The Silhouette Coefficient is 0.11525675865441426
# For n_clusters=26, The homogeneity_score is 0.4941849081817139
# For n_clusters=27, The Silhouette Coefficient is 0.11719873677875631
# For n_clusters=27, The homogeneity_score is 0.4886651352956225
# For n_clusters=28, The Silhouette Coefficient is 0.11708322705687192
# For n_clusters=28, The homogeneity_score is 0.4909645085436008
# For n_clusters=29, The Silhouette Coefficient is 0.11780447922106245
# For n_clusters=29, The homogeneity_score is 0.49138819684408935
# For n_clusters=30, The Silhouette Coefficient is 0.11743639579071187
# For n_clusters=30, The homogeneity_score is 0.500398516330484

# %%
from sklearn.mixture import GaussianMixture
silh_wine_EM = {}
homog__wine_EM = {}
log_likelihood_wine_EM = {}
for cluster in clusters:
    gmm = GaussianMixture(n_components=cluster, max_iter=100, random_state=44, 
                          n_init=5).fit(wineX_grp_9)
    label = gmm.predict(wineX_grp_9)
    sil_coeff = silhouette_score(wineX_grp_9, label, metric='euclidean')
    homog_score = homogeneity_score(wineY, label)
    silh_wine_EM[cluster] = sil_coeff
    homog__wine_EM[cluster] = homog_score
    log_likelihood_wine_EM[cluster] = gmm.score(wineX_grp_9)
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(cluster, sil_coeff))
    print("For n_clusters={}, The homogeneity_score is {}".format(cluster, homog_score))
    print("For n_clusters={}, The log_likelihood score is {}".format(cluster, log_likelihood_wine_EM[cluster]))
plt.figure()
plt.plot(list(silh_wine_EM.keys()), list(silh_wine_EM.values()))
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
plt.show()
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.2547925530550032
# For n_clusters=2, The homogeneity_score is 0.2567540529193886
# For n_clusters=2, The log_likelihood score is 0.4536496613176403
# For n_clusters=3, The Silhouette Coefficient is 0.16631728135204663
# For n_clusters=3, The homogeneity_score is 0.39612849882239476
# For n_clusters=3, The log_likelihood score is 0.581315881237314
# For n_clusters=4, The Silhouette Coefficient is 0.07508030222224535
# For n_clusters=4, The homogeneity_score is 0.3660693847570919
# For n_clusters=4, The log_likelihood score is 0.6821328748893122
# For n_clusters=5, The Silhouette Coefficient is 0.0761799925296418
# For n_clusters=5, The homogeneity_score is 0.44280409000730064
# For n_clusters=5, The log_likelihood score is 0.753830292084135
# For n_clusters=6, The Silhouette Coefficient is 0.057838380165070716
# For n_clusters=6, The homogeneity_score is 0.4910519006686404
# For n_clusters=6, The log_likelihood score is 0.7901603726071879
# For n_clusters=7, The Silhouette Coefficient is 0.03957546158644612
# For n_clusters=7, The homogeneity_score is 0.4945598082161238
# For n_clusters=7, The log_likelihood score is 0.8197048003369888
# For n_clusters=8, The Silhouette Coefficient is 0.03204316870438115
# For n_clusters=8, The homogeneity_score is 0.48073987493848186
# For n_clusters=8, The log_likelihood score is 0.8432704435063934
# For n_clusters=9, The Silhouette Coefficient is 0.025916786622129588
# For n_clusters=9, The homogeneity_score is 0.5241738008718629
# For n_clusters=9, The log_likelihood score is 0.8715020270331135
# For n_clusters=10, The Silhouette Coefficient is 0.03438838549521758
# For n_clusters=10, The homogeneity_score is 0.5268096093675381
# For n_clusters=10, The log_likelihood score is 0.8877637319113805
# For n_clusters=11, The Silhouette Coefficient is 0.022172629147572655
# For n_clusters=11, The homogeneity_score is 0.515107981170584
# For n_clusters=11, The log_likelihood score is 0.9110707187672784
# For n_clusters=12, The Silhouette Coefficient is -0.002985037910669332
# For n_clusters=12, The homogeneity_score is 0.5127176162584379
# For n_clusters=12, The log_likelihood score is 0.9298240789279442
# For n_clusters=13, The Silhouette Coefficient is -0.0007476874911502764
# For n_clusters=13, The homogeneity_score is 0.5404072869950052
# For n_clusters=13, The log_likelihood score is 0.9411097859642134
# For n_clusters=14, The Silhouette Coefficient is 0.0004211407643037446
# For n_clusters=14, The homogeneity_score is 0.5324172411009805
# For n_clusters=14, The log_likelihood score is 0.9553952763826952
# For n_clusters=15, The Silhouette Coefficient is 0.002406039075133113
# For n_clusters=15, The homogeneity_score is 0.5246950745019466
# For n_clusters=15, The log_likelihood score is 0.9727115372041375
# For n_clusters=16, The Silhouette Coefficient is -0.0100342428904831
# For n_clusters=16, The homogeneity_score is 0.5276318530167134
# For n_clusters=16, The log_likelihood score is 0.9863820626363188
# For n_clusters=17, The Silhouette Coefficient is -0.009720762397225406
# For n_clusters=17, The homogeneity_score is 0.5136216940158717
# For n_clusters=17, The log_likelihood score is 0.9971372031556289
# For n_clusters=18, The Silhouette Coefficient is 0.002078941744978892
# For n_clusters=18, The homogeneity_score is 0.5412646173569661
# For n_clusters=18, The log_likelihood score is 1.0074821171413926
# For n_clusters=19, The Silhouette Coefficient is -0.015219169349195804
# For n_clusters=19, The homogeneity_score is 0.521770111167715
# For n_clusters=19, The log_likelihood score is 1.035118041935004
# For n_clusters=20, The Silhouette Coefficient is -0.004895229105229545
# For n_clusters=20, The homogeneity_score is 0.5264589045681037
# For n_clusters=20, The log_likelihood score is 1.040296419838667
# For n_clusters=21, The Silhouette Coefficient is -0.0022789948164026676
# For n_clusters=21, The homogeneity_score is 0.5366389413439937
# For n_clusters=21, The log_likelihood score is 1.0530071031124955
# For n_clusters=22, The Silhouette Coefficient is -0.005953239542675601
# For n_clusters=22, The homogeneity_score is 0.5414215030949703
# For n_clusters=22, The log_likelihood score is 1.07296749678764
# For n_clusters=23, The Silhouette Coefficient is -0.012470457250264643
# For n_clusters=23, The homogeneity_score is 0.5309583772487562
# For n_clusters=23, The log_likelihood score is 1.0671373708613203
# For n_clusters=24, The Silhouette Coefficient is -0.010843797805151404
# For n_clusters=24, The homogeneity_score is 0.5343781139410857
# For n_clusters=24, The log_likelihood score is 1.0860676512850582
# For n_clusters=25, The Silhouette Coefficient is -0.007433508263880864
# For n_clusters=25, The homogeneity_score is 0.5351438559192805
# For n_clusters=25, The log_likelihood score is 1.1021363420574053
# For n_clusters=26, The Silhouette Coefficient is -0.025534759184650705
# For n_clusters=26, The homogeneity_score is 0.5389382348167101
# For n_clusters=26, The log_likelihood score is 1.1056355343290598
# For n_clusters=27, The Silhouette Coefficient is -0.017331981694169094
# For n_clusters=27, The homogeneity_score is 0.5193581572709455
# For n_clusters=27, The log_likelihood score is 1.1228012735686073
# For n_clusters=28, The Silhouette Coefficient is -0.008757681170693593
# For n_clusters=28, The homogeneity_score is 0.5283478824187767
# For n_clusters=28, The log_likelihood score is 1.1323044722842048
# For n_clusters=29, The Silhouette Coefficient is -0.018249608254605584
# For n_clusters=29, The homogeneity_score is 0.5404388217581115
# For n_clusters=29, The log_likelihood score is 1.1413595588104082
# For n_clusters=30, The Silhouette Coefficient is -0.014559355488659593
# For n_clusters=30, The homogeneity_score is 0.5415939583346961
# For n_clusters=30, The log_likelihood score is 1.1632810920894463

# %% [markdown]
# ## Neural Network on Randomized Projections

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)
from sklearn.neural_network import MLPClassifier
neural_net = MLPClassifier()
neural_net.fit(wineX_grp_9, wineY)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
# first net results
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report
ufc_train_predictions = neural_net.predict(wineX_grp_9)
accuracy = accuracy_score(wineY, ufc_train_predictions)
print(accuracy)
print(classification_report(wineY, ufc_train_predictions))
# Out:
# 0.862
#               precision    recall  f1-score   support
#
#            1       0.86      0.90      0.88      1577
#            2       0.86      0.83      0.85      2013
#            3       0.87      0.87      0.87      1410
#
#     accuracy                           0.86      5000
#    macro avg       0.86      0.86      0.86      5000
# weighted avg       0.86      0.86      0.86      5000

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(neural_net, wineX_grp_9, wineY,
                         scoring="f1_weighted", cv=10)
scores, scores.mean()
# Out:
# (array([0.84000462, 0.84202064, 0.8638037 , 0.84763087, 0.86794017,
#         0.84161428, 0.86402869, 0.86980681, 0.86063048, 0.86404013]),
#  0.8561520404468569)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(wineX_grp_9, 
                                                    wineY, 
                                                    test_size=0.33, 
                                                    random_state=42,
                                                    stratify=wineY)

# %%
# stratified cross validation
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone

def stratFold(train_X_all, train_y_all, classifier, metric, average=None,
              fold=5):
    train_metric, val_metric, indices = [], [], []
    for m in range(100, len(train_X_all), 100):
        train_X = train_X_all[:m]
        train_y = train_y_all[:m]
        skfolds = StratifiedKFold(n_splits=fold)
        metric_list = []
        metric_list_train = []
        for train_index, test_index in skfolds.split(train_X, train_y):
            train_X_folds = train_X[train_index, :]
            train_y_folds = train_y[train_index]
            test_X_fold = train_X[test_index, :]
            test_y_fold = train_y[test_index]
            classifier.fit(train_X_folds, train_y_folds)
            train_y_folds_pred = classifier.predict(train_X_folds)
            test_y_fold_pred = classifier.predict(test_X_fold)
            if average:
                metric_list.append(metric(test_y_fold, test_y_fold_pred,
                                     average=average))
                metric_list_train.append(metric(train_y_folds, train_y_folds_pred, 
                                            average=average))
            else:
                metric_list.append(metric(test_y_fold, test_y_fold_pred))
                metric_list_train.append(metric(train_y_folds, train_y_folds_pred))
                
        test_avg = sum(metric_list)/len(metric_list)
        train_avg = sum(metric_list_train)/len(metric_list_train)
        val_metric.append(test_avg)
        train_metric.append(train_avg)
        indices.append(m)
    
    return train_metric, val_metric, indices

# %%
def plot_complexity(train_scores, val_scores, indices, title, inverse_x=True):
    plt.plot(indices, train_scores , "r-+", linewidth=2, label="train")
    plt.plot(indices, val_scores, "b-+", linewidth=2, label="validation")
    plt.title(title)
    plt.legend()
    plt.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.3)
    if inverse_x:
        plt.gca().invert_xaxis()

# %%
def plot_learning_curve(train_scores, val_scores, indices, title, inverse_x=False):
    plt.plot(indices, train_scores , "r-+", linewidth=2, label="train")
    plt.plot(indices, val_scores, "b-+", linewidth=2, label="validation")
    plt.title(title)
    plt.legend()
    plt.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.3)
    if inverse_x:
        plt.gca().invert_xaxis()

# %%
from sklearn.metrics import f1_score
f1_scores = stratFold(X_train, y_train, neural_net, f1_score, 
                      average="weighted")
plot_learning_curve(f1_scores[0], f1_scores[1], f1_scores[2], 
                    title="f1_weighted score learning curve")

# %%
# start with the best net from Assignment 1
best_net  = MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
              beta_2=0.999, early_stopping=False, epsilon=1e-08,
              hidden_layer_sizes=(60, 60), learning_rate='invscaling',
              learning_rate_init=0.001, max_fun=15000, max_iter=200,
              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
              power_t=0.5, random_state=None, shuffle=True, solver='adam',
              tol=0.0001, validation_fraction=0.1, verbose=False,
              warm_start=False)

# %%
from sklearn.model_selection import validation_curve
params = [60, 80, 100]
param_range = [(60,60), (80,80), (100,100)]

train_scores, test_scores = validation_curve(
    best_net, X_train, y_train, param_name="hidden_layer_sizes", 
    param_range=param_range, scoring='f1_weighted', verbose=1, cv=5, n_jobs=-1
)
print(train_scores.mean(axis=1), test_scores.mean(axis=1), param_range)
plot_complexity(train_scores.mean(axis=1), test_scores.mean(axis=1), params, 
                title='f1_weighted on 2-layer hidden_layer complexity curve', inverse_x=True)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   35.5s finished
# [0.86640859 0.86683104 0.86781169] [0.85852794 0.85408349 0.85712661] [(60, 60), (80, 80), (100, 100)]

# %%
# start with the best net from Assignment 1
best_net_RP = MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
              beta_2=0.999, early_stopping=False, epsilon=1e-08,
              hidden_layer_sizes=(60, 60), learning_rate='invscaling',
              learning_rate_init=0.001, max_fun=15000, max_iter=200,
              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
              power_t=0.5, random_state=None, shuffle=True, solver='adam',
              tol=0.0001, validation_fraction=0.1, verbose=False,
              warm_start=False)

# %%
from sklearn.metrics import f1_score
f1_scores = stratFold(X_train, y_train, best_net_RP, 
                      f1_score, average="weighted")
plot_learning_curve(f1_scores[0], f1_scores[1], f1_scores[2], title="f1_scores")

# %%
from sklearn.metrics import confusion_matrix
best_net_RP.fit(X_train, y_train)
test_predictions = best_net_RP.predict(X_test)
print(classification_report(y_test, test_predictions, digits=5))
print(confusion_matrix(y_test, test_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1    0.86882   0.87716   0.87297       521
#            2    0.82840   0.84337   0.83582       664
#            3    0.86607   0.83441   0.84995       465
#
#     accuracy                        0.85152      1650
#    macro avg    0.85443   0.85165   0.85291      1650
# weighted avg    0.85178   0.85152   0.85153      1650
#
# [[457  51  13]
#  [ 57 560  47]
#  [ 12  65 388]]
